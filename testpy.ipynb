# %%
# %load_ext autoreload
# %autoreload 2

import numpy  as np
import pandas as pd
import h5py
from pathlib import Path

from astropy    import units as u
import matplotlib
from matplotlib import pyplot as plt
import matplotlib.patches as mpatches
# matplotlib.use('Agg')

from scipy.interpolate import RegularGridInterpolator
from scipy.signal      import argrelextrema

from common import hallmark as hm
from common import mockservation as mk
from common import io_raptor as io
from common import dalt
from common import viz

import plotscripts
from plotscripts import subtract, image2d, loadfigure, getimagedata

import rapplot

from module import *

# %%
#Computing relevant constants
M=5e6 * rapplot.MSUN
d=8 * rapplot.KPC

rg = (rapplot.G*M/rapplot.SPEED_OF_LIGHT**2.)

mas = (rg/d)* rapplot.MAS_IN_DEG

Tunit =rg/rapplot.SPEED_OF_LIGHT


halfrange=20 #in rg

# %% [markdown]
# ## Plot High Res image

# %%
plt.figure(figsize=(30,30),facecolor='w')
fig, ax = plt.subplots(1,1,figsize=(5,4), sharex=True, sharey=True)
img_path = "cache/Ma101_w1/Rh1_i60"

# get image
data_id_all, min, max, image_array = subtract(img_path+"/n100", img_path+"/n0", 999 , ave=False)
# data_id_all, min, max, image_array = getimagedata(img_path+'/n100', 999)


#get critical curve 
alpha1, beta1 = import_ab(1.01, 60, True) 
# connect edge
alpha_closed = np.r_[alpha1[0:200000], alpha1[1]]
beta_closed =  np.r_[beta1[0:200000], beta1[1]] 

# plot original arc 
ax.plot(alpha1, beta1, linewidth=1, color='deepskyblue', linestyle='-')
# plot connecting line 
ax.plot(alpha_closed, beta_closed, linewidth=1, color='deepskyblue', linestyle='--')

# inner, outter = extractimg_inout(image_array, alpha1, beta1)

figure = loadfigure(image_array, np.min(image_array), np.max(image_array), fig, ax, 20, 1, label="Stokes", cmap="afmhot")

ax.set_xlabel(r"x [mas]")
ax.set_ylabel(r"y [mas]")
ax.set_xlim(-8, 8)
ax.set_ylim(-8, 8)

fig.colorbar(figure, ax=ax)
fig.savefig(f"output/plot/HPR_avei60.jpg", dpi=1000)
# fig.savefig(f"HPR.pdf")
# Out:
# read from cache/Ma101_w1/Rh1_i60/n100 and cache/Ma101_w1/Rh1_i60/n0
# Reading in:  cache/Ma101_w1/Rh1_i60/n100/img_data_999.h5
# 8
# Reading in:  cache/Ma101_w1/Rh1_i60/n0/img_data_999.h5
# 8

# %% [markdown]
# ## Higher order photon rings structures

# %%
# Load all images 
pf = hm.ParaFrame('cache/{mag}a{aspin:g}_w{window:d}/Rh{Rhigh:d}_i{inc:d}/n{n:n}/img_data_{snapshot:d}.h5')
sel = pf(snapshot=[999, 1000])
display(sel)
# Out:
#                                             path mag  aspin  window  Rhigh  \
# 1      cache/Ma101_w1/Rh1_i15/n0/img_data_999.h5   M  101.0       1      1
# 2     cache/Ma101_w1/Rh1_i15/n1/img_data_1000.h5   M  101.0       1      1
# 5      cache/Ma101_w1/Rh1_i15/n1/img_data_999.h5   M  101.0       1      1
# 7    cache/Ma101_w1/Rh1_i15/n100/img_data_999.h5   M  101.0       1      1
# 8     cache/Ma101_w1/Rh1_i15/n2/img_data_1000.h5   M  101.0       1      1
# 11     cache/Ma101_w1/Rh1_i15/n2/img_data_999.h5   M  101.0       1      1
# 14     cache/Ma101_w1/Rh1_i30/n0/img_data_999.h5   M  101.0       1      1
# 15    cache/Ma101_w1/Rh1_i30/n1/img_data_1000.h5   M  101.0       1      1
# 18     cache/Ma101_w1/Rh1_i30/n1/img_data_999.h5   M  101.0       1      1
# 20   cache/Ma101_w1/Rh1_i30/n100/img_data_999.h5   M  101.0       1      1
# 21    cache/Ma101_w1/Rh1_i30/n2/img_data_1000.h5   M  101.0       1      1
# 24     cache/Ma101_w1/Rh1_i30/n2/img_data_999.h5   M  101.0       1      1
# 26     cache/Ma101_w1/Rh1_i45/n0/img_data_999.h5   M  101.0       1      1
# 27    cache/Ma101_w1/Rh1_i45/n1/img_data_1000.h5   M  101.0       1      1
# 30     cache/Ma101_w1/Rh1_i45/n1/img_data_999.h5   M  101.0       1      1
# 32   cache/Ma101_w1/Rh1_i45/n100/img_data_999.h5   M  101.0       1      1
# 33    cache/Ma101_w1/Rh1_i45/n2/img_data_1000.h5   M  101.0       1      1
# 36     cache/Ma101_w1/Rh1_i45/n2/img_data_999.h5   M  101.0       1      1
# 39     cache/Ma101_w1/Rh1_i60/n0/img_data_999.h5   M  101.0       1      1
# 40    cache/Ma101_w1/Rh1_i60/n1/img_data_1000.h5   M  101.0       1      1
# 43     cache/Ma101_w1/Rh1_i60/n1/img_data_999.h5   M  101.0       1      1
# 44  cache/Ma101_w1/Rh1_i60/n100/img_data_1000.h5   M  101.0       1      1
# 50   cache/Ma101_w1/Rh1_i60/n100/img_data_999.h5   M  101.0       1      1
# 51    cache/Ma101_w1/Rh1_i60/n2/img_data_1000.h5   M  101.0       1      1
# 54     cache/Ma101_w1/Rh1_i60/n2/img_data_999.h5   M  101.0       1      1
# 55     cache/Ma101_w1/Rh1_i75/n0/img_data_999.h5   M  101.0       1      1
# 56    cache/Ma101_w1/Rh1_i75/n1/img_data_1000.h5   M  101.0       1      1
# 57     cache/Ma101_w1/Rh1_i75/n1/img_data_999.h5   M  101.0       1      1
# 58   cache/Ma101_w1/Rh1_i75/n100/img_data_999.h5   M  101.0       1      1
# 59    cache/Ma101_w1/Rh1_i75/n2/img_data_1000.h5   M  101.0       1      1
# 60     cache/Ma101_w1/Rh1_i75/n2/img_data_999.h5   M  101.0       1      1
#
#     inc    n  snapshot
# 1    15    0       999
# 2    15    1      1000
# 5    15    1       999
# 7    15  100       999
# 8    15    2      1000
# 11   15    2       999
# 14   30    0       999
# 15   30    1      1000
# 18   30    1       999
# 20   30  100       999
# 21   30    2      1000
# 24   30    2       999
# 26   45    0       999
# 27   45    1      1000
# 30   45    1       999
# 32   45  100       999
# 33   45    2      1000
# 36   45    2       999
# 39   60    0       999
# 40   60    1      1000
# 43   60    1       999
# 44   60  100      1000
# 50   60  100       999
# 51   60    2      1000
# 54   60    2       999
# 55   75    0       999
# 56   75    1      1000
# 57   75    1       999
# 58   75  100       999
# 59   75    2      1000
# 60   75    2       999

# %%
ns = np.sort( np.array(sel.n.unique()))
incs = np.sort(np.array(sel.inc.unique())) 

print("n: ", ns)
print("inc: ", incs[0:len(incs)])
# Out:
# n:  [  0   1   2 100]
# inc:  [15 30 45 60 75]

# %%
# substruct 
# for n in [1,2]: 
#     for inc in incs: 

#         try:
#             s_0 = sel[(sel['inc']==inc) & (sel['n']==n ) & (sel['snapshot']==999)]
#             s_1 = sel[(sel['inc']==inc) & (sel['n']==(n-1)) & (sel['snapshot']==999) ]

#             path_object_0 = Path(s_0.path.item())
#             img_path_0 = str( path_object_0.parent )
#             path_object_1 = Path(s_1.path.item())
#             img_path_1 = str( path_object_1.parent )

#             subtract(img_path_0, img_path_1, 999 , ave=False)

#         except: 
#             print("Error: ", inc, n)

# %%
fig, axes = plt.subplots(len(incs), len(ns)+1, figsize=(8, 6), sharex=True, sharey=True)

fig.patch.set_facecolor('white')

for column, inc in enumerate(incs[0:len(incs)]):
    imgs_list = []
    for row, n in enumerate(ns): 
        ax = axes[column, row]

        if n in [1, 2]:
            s = sel[(sel['inc'] == inc) & (sel['n'] == n) & (sel['snapshot'] == 1000)]
            snapshot = 1000
        else:
            s = sel[(sel['inc'] == inc) & (sel['n'] == n) & (sel['snapshot'] == 999)]
            snapshot = 999

        if s.path.shape == (1,): 
            path_object = Path(s.path.item())
            img_path = str(path_object.parent)
            data_id_all, min, max, image_array = getimagedata(img_path, snapshot)
            figure = loadfigure(image_array, min, max, fig, ax, 20, 1, label="Stokes", cmap="afmhot")
            ax.set_xlim(-8, 8)
            ax.set_ylim(-8, 8)
        else: 
            print("error", inc, n)

        if n in [0, 1, 2]:
            imgs_list.append(image_array)

        

        if column == 0:
            if n == 100:
                ax.set_title("Total", fontsize=10)
            else:
                ax.set_title(f"n = {n}", fontsize=10)

    axes[column, 0].set_ylabel(f"i = {inc}", fontsize=10, rotation=0, labelpad=20, va='center')

    imgs = np.stack(imgs_list, axis=0)
    if row + 1 < axes.shape[1]:
        legend_handles = plotregion(imgs, axes[column, row+1])

fig.legend(handles=legend_handles,
           bbox_to_anchor=(0.98, 0.95),
           fontsize=8,
           frameon=False)

# Colorbar
cbar_ax = fig.add_axes([0.0, 0.15, 0.02, 0.7])
fig.colorbar(figure, cax=cbar_ax, orientation='vertical')

# Layout adjustments
fig.subplots_adjust(left=0.2, right=0.85, top=0.9, bottom=0.1, wspace=0.1, hspace=0.2)
# Save
fig.savefig("output/table/hpr.jpg", bbox_inches='tight', dpi=300)
# Out:
# Reading in:  cache/Ma101_w1/Rh1_i15/n0/img_data_999.h5
# 8
# Reading in:  cache/Ma101_w1/Rh1_i15/n1/img_data_1000.h5
# 8
# Reading in:  cache/Ma101_w1/Rh1_i15/n2/img_data_1000.h5
# 8
# Reading in:  cache/Ma101_w1/Rh1_i15/n100/img_data_999.h5
# 8
# Reading in:  cache/Ma101_w1/Rh1_i30/n0/img_data_999.h5
# 8
# Reading in:  cache/Ma101_w1/Rh1_i30/n1/img_data_1000.h5
# 8
# Reading in:  cache/Ma101_w1/Rh1_i30/n2/img_data_1000.h5
# 8
# Reading in:  cache/Ma101_w1/Rh1_i30/n100/img_data_999.h5
# 8
# Reading in:  cache/Ma101_w1/Rh1_i45/n0/img_data_999.h5
# 8
# Reading in:  cache/Ma101_w1/Rh1_i45/n1/img_data_1000.h5
# 8
# Reading in:  cache/Ma101_w1/Rh1_i45/n2/img_data_1000.h5
# 8
# Reading in:  cache/Ma101_w1/Rh1_i45/n100/img_data_999.h5
# 8
# Reading in:  cache/Ma101_w1/Rh1_i60/n0/img_data_999.h5
# 8
# Reading in:  cache/Ma101_w1/Rh1_i60/n1/img_data_1000.h5
# 8
# Reading in:  cache/Ma101_w1/Rh1_i60/n2/img_data_1000.h5
# 8
# Reading in:  cache/Ma101_w1/Rh1_i60/n100/img_data_999.h5
# 8
# Reading in:  cache/Ma101_w1/Rh1_i75/n0/img_data_999.h5
# 8
# Reading in:  cache/Ma101_w1/Rh1_i75/n1/img_data_1000.h5
# 8
# Reading in:  cache/Ma101_w1/Rh1_i75/n2/img_data_1000.h5
# 8
# Reading in:  cache/Ma101_w1/Rh1_i75/n100/img_data_999.h5
# 8

# %% [markdown]
# ## VAs per angle

# %%
fig, axes = plt.subplots(5, 1, figsize=(8, 6), sharex=True, sharey=True)

legend_handles = []  

for row, inc in enumerate(incs[0:len(incs)]):
    ax = axes[row]
    
    for col, n in enumerate(ns): 
        if n in [1, 2]: 
            s = sel[(sel['inc'] == inc) & (sel['n'] == n) & (sel['snapshot'] == 1000)]
        else: 
            s = sel[(sel['inc'] == inc) & (sel['n'] == n) & (sel['snapshot'] == 999)]
        
        path_object = Path(s.path.item())
        mov = io.load_mov(s.path, [1000 if n in [1, 2] else 999])
        
        # Plot VA

        handles = plot_va(mov, ax, n)
        if handles:
            legend_handles.extend(handles)

            
    ax.text(0.7, 0.9, f"i = {inc}", transform=ax.transAxes,
            fontsize=10, ha='right', va='top')

    print("DONE:", inc)

fig.legend(handles=legend_handles[0:4],
           fontsize=10,
           bbox_to_anchor=(0.9, 0.9),
           frameon=True)

fig.supxlabel(r"Baseline Length u ($G\lambda$)")
fig.supylabel("Visibility Amplitude (Jy)")   
fig.savefig("output/table/va.pdf", bbox_inches='tight')
# Out:
# DONE: 15
# DONE: 30
# DONE: 45
# DONE: 60
# DONE: 75
